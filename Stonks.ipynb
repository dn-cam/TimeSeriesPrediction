# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

#for time series
from pandas import Series

# %%
data_raw = pd.read_csv('data.csv')

# %%
data_raw.head()
# Out:
#   TICKER          FIGI        DATE      TYPE FREQUENCY   OPEN     HIGH    LOW  \
# 0    GEF  BBG000BLFQH8  2013-01-04       EOD     daily  46.31  47.6198  46.23
# 1    GEF  BBG000BLFQH8  2013-01-03       EOD     daily  46.43  46.5200  46.14
# 2    GEF  BBG000BLFQH8  2013-01-02       EOD     daily  45.38  46.5400  45.16
# 3     GF  BBG000C3C6S2  2018-06-05  Intraday     daily  18.86  18.9100  18.87
# 4     GF  BBG000C3C6S2  2018-06-04       EOD     daily  18.86  18.8900  18.79
#
#    CLOSE    VOLUME   ADJ_OPEN   ADJ_HIGH    ADJ_LOW  ADJ_CLOSE  ADJ_VOLUME  \
# 0  47.37  248000.0  38.517220  39.606614  38.450681  39.398849    248000.0
# 1  46.48  131300.0  38.617027  38.691882  38.375826  38.658613    131300.0
# 2  46.41  184900.0  37.743715  38.708516  37.560735  38.600392    184900.0
# 3  18.87   10000.0  18.860000  18.910000  18.870000  18.870000     10000.0
# 4  18.81   39095.0  18.860000  18.890000  18.790000  18.810000     39095.0
#
#    ADJ_FACTOR  EX_DIVIDEND  SPLIT_RATIO
# ...

# %%
data_raw.size
# Out:
# 17982

# %% [markdown]
# ### Sort the data by Date, and filter out only the data for the stock "GF"

# %%
data_1 = data_raw
data_1['DATE'] = pd.to_datetime(data_1.DATE)

# %%
data_1.sort_values(by='DATE')
# Out:
#     TICKER          FIGI       DATE      TYPE FREQUENCY     OPEN     HIGH  \
# 2      GEF  BBG000BLFQH8 2013-01-02       EOD     daily  45.3800  46.5400
# 1      GEF  BBG000BLFQH8 2013-01-03       EOD     daily  46.4300  46.5200
# 0      GEF  BBG000BLFQH8 2013-01-04       EOD     daily  46.3100  47.6198
# 998     GF  BBG000C3C6S2 2014-06-23       EOD     daily  19.0500  19.0500
# 997     GF  BBG000C3C6S2 2014-06-24       EOD     daily  18.9100  18.9500
# 996     GF  BBG000C3C6S2 2014-06-25       EOD     daily  18.6600  18.7200
# 995     GF  BBG000C3C6S2 2014-06-26       EOD     daily  18.5200  18.5901
# 994     GF  BBG000C3C6S2 2014-06-27       EOD     daily  18.6300  18.6300
# 993     GF  BBG000C3C6S2 2014-06-30       EOD     daily  18.6800  18.8000
# 992     GF  BBG000C3C6S2 2014-07-01       EOD     daily  18.6800  18.9200
# 991     GF  BBG000C3C6S2 2014-07-02       EOD     daily  18.7400  18.8100
# 990     GF  BBG000C3C6S2 2014-07-03       EOD     daily  18.8600  18.9990
# ...

# %%
data_gf = data_1[data_1.TICKER == 'GF']

# %% [markdown]
# ### Plotting the Autocorrelation Plot

# %%
series = data_gf.set_index('DATE')
ts = series.cumsum()

ts.plot(figsize=(15, 10))

# %%
plt.figure(figsize=(17, 8))
plt.plot(data_gf.DATE, data_gf.CLOSE)
plt.xlabel('Dates', fontsize=15)
plt.ylabel('Closing Price', fontsize=15)
plt.title("GF Stock Closing Prices")
# Out:
# Text(0.5,1,'GF Stock Closing Prices')

# %%
data_gf.head()
# Out:
#   TICKER          FIGI       DATE      TYPE FREQUENCY   OPEN    HIGH      LOW  \
# 3     GF  BBG000C3C6S2 2018-06-05  Intraday     daily  18.86  18.910  18.8700
# 4     GF  BBG000C3C6S2 2018-06-04       EOD     daily  18.86  18.890  18.7900
# 5     GF  BBG000C3C6S2 2018-06-01       EOD     daily  18.58  18.760  18.5800
# 6     GF  BBG000C3C6S2 2018-05-31       EOD     daily  18.52  18.520  18.3012
# 7     GF  BBG000C3C6S2 2018-05-30       EOD     daily  18.47  18.678  18.4700
#
#    CLOSE   VOLUME  ADJ_OPEN  ADJ_HIGH  ADJ_LOW  ADJ_CLOSE  ADJ_VOLUME  \
# 3  18.87  10000.0     18.86    18.910  18.8700      18.87     10000.0
# 4  18.81  39095.0     18.86    18.890  18.7900      18.81     39095.0
# 5  18.74  17468.0     18.58    18.760  18.5800      18.74     17468.0
# 6  18.49  22384.0     18.52    18.520  18.3012      18.49     22384.0
# 7  18.65  22633.0     18.47    18.678  18.4700      18.65     22633.0
#
#    ADJ_FACTOR  EX_DIVIDEND  SPLIT_RATIO
# ...

# %%
drop_columns = ['TICKER', 'FIGI', 'TYPE', 'FREQUENCY', 'VOLUME', 'ADJ_OPEN', 'ADJ_HIGH', 'ADJ_LOW', 'ADJ_CLOSE', 'ADJ_VOLUME', 'ADJ_FACTOR', 'EX_DIVIDEND', 'SPLIT_RATIO']
data_gf.drop(drop_columns, axis = 1, inplace=True)
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.py:3930: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
data_gf.head()
series = data_gf.set_index('DATE')
ts = series.cumsum()

series.CLOSE.plot(figsize=(15, 10))

# %% [markdown]
# ### Moving Average

# %%
rolling_3 = series.rolling(window=3)
rolling_3_mean = rolling_3.mean()
print(rolling_3_mean.head(10))
# plot original and transformed dataset
series.CLOSE.plot(fig=(15, 10))
rolling_3_mean.CLOSE.plot(fig=(15, 10), color='red')
plt.show()

# %%
rolling_5 = series.rolling(window=5)
rolling_5_mean = rolling_5.mean()

rolling_10 = series.rolling(window=10)
rolling_10_mean = rolling_10.mean()

rolling_15 = series.rolling(window=15)
rolling_15_mean = rolling_15.mean()

rolling_20 = series.rolling(window=20)
rolling_20_mean = rolling_20.mean()

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15,10))
plt.subplot(3, 2, 1)
series.CLOSE.plot()
plt.xlabel('window = 1')
plt.subplot(3, 2, 2)
rolling_3_mean.CLOSE.plot()
plt.xlabel('window = 3')
plt.subplot(3, 2, 3)
rolling_5_mean.CLOSE.plot()
plt.xlabel('window = 5')
plt.subplot(3, 2, 4)
rolling_10_mean.CLOSE.plot()
plt.xlabel('window = 10')
plt.subplot(3, 2, 5)
rolling_15_mean.CLOSE.plot()
plt.xlabel('window = 15')
plt.subplot(3, 2,6)
rolling_20_mean.CLOSE.plot()
plt.xlabel('window = 20')
fig.tight_layout()

# %% [markdown]
# Since the smoothing is not significant with windows of size even 20, we can try smoothing over a month, a quarter and a year.

# %%
rolling_30 = series.rolling(window=30)
rolling_30_mean = rolling_30.mean()

rolling_90 = series.rolling(window=90)
rolling_90_mean = rolling_90.mean()

rolling_365 = series.rolling(window=365)
rolling_365_mean = rolling_365.mean()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15,10))
plt.subplot(2, 2, 1)
series.CLOSE.plot()
plt.xlabel('window = 1')
plt.subplot(2, 2, 2)
rolling_30_mean.CLOSE.plot()
plt.xlabel('window = 1 mo')
plt.subplot(2, 2, 3)
rolling_90_mean.CLOSE.plot()
plt.xlabel('window = 1 qt')
plt.subplot(2, 2, 4)
rolling_365_mean.CLOSE.plot()
plt.xlabel('window = 1 yr')
fig.tight_layout()

# %% [markdown]
# ### Exponential Smoothing

# %%
data_gf.CLOSE.iloc[0]
# Out:
# 18.87

# %%
def exponentialSmoothing(df, alpha):
    # y = ax_sub_t + (1-a)y_sub_(t-1)
    result = [df.iloc[0]]
    for n in range(1, len(df)):
        result.append(alpha*df.iloc[n] + (1-alpha)*result[n-1])
    return result

def plotExpoSmoothing(df, alphaArray):
    plt.figure(figsize=(20,10))
    for alpha in alphaArray:
        plt.plot(exponentialSmoothing(df, alpha), label="Alpha {}".format(alpha))
    plt.plot(df.values, "c", label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Exponential Smoothing")
    plt.grid(True);

plotExpoSmoothing(data_gf.CLOSE, [0.05, 0.3, 0.5])

# %% [markdown]
# ### Dickey-Fuller test for stationarity

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(series.CLOSE)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -1.483585
# p-value: 0.541615
